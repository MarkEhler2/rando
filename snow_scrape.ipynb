# %%
from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.multipart import MIMEMultipart
from bs4 import BeautifulSoup
import datetime
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions

# %%
Me = "Users/Mark/Downloads"

chromedriver_path = f'C:/{Me}/chromedriver_win32/chromedriver.exe'

search_query = 'https://www.nohrsc.noaa.gov/snowfall_v2/'

# %%
driver = webdriver.Chrome(executable_path=chromedriver_path)
sleep(2)
driver.get(search_query)

# %%
duration = '//*[@id="interface_version"]/option[1]'
driver.find_element_by_xpath(duration).click()

# %%
season = '//*[@id="interface_season"]'
seasons = driver.find_element_by_xpath(season)#.select()
select = Select(seasons)
options = select.options
sleep(6)
for i in range(4,len(options)-1):
    print(options[i].text)
    option = options[i].text
    select.select_by_value(option)
    
    date = '//*[@id="interface_date"]'
    dates = driver.find_element_by_xpath(date)
    date_select = Select(dates)
    date_options = date_select.options
    date_list = []
    for j in range(0,len(date_options)-1):
    #     print(date_options[j].text)
        date_option = date_options[j].text.strip(' UTC')
        date_option = date_option.replace(' ', '')
        date_option = date_option.replace('-', '')
        date_list.append(date_option)
        init_list = []
        for k in date_list:
#             print(k)
            if k.endswith('12'):
                init_list.append(k)
            else:
                continue

    print(init_list)
    for l in init_list:
        date_select.select_by_value(l)
        sleep(1)
        geotiff = '//*[@id="format"]/option[2]'
        driver.find_element_by_xpath(geotiff).click()
        print('waiting')
        sleep(10)
        print('waited')
#         print('before check')
#         my_element_id = 'something123'
#         ignored_exceptions=(NoSuchElementException,StaleElementReferenceException,)
#         your_element = WebDriverWait(driver, 30,ignored_exceptions=ignored_exceptions)\
#                         .until(expected_conditions.presence_of_element_located((By.ID, my_element_id)))
#         print('after check')
# Out:
# 2017-2018
# ...
